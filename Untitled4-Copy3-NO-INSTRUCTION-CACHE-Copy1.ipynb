# %%
library("factoextra")
options(repr.plot.width=12, repr.plot.height=13)

# %%
path="C:/Users/Jordi/"
setwd(path)
mydata = read.csv("data-all.csv", sep=";")

# %%
head(mydata)
# Out:
#   id size.vector comp.opt label  PAPI_L1_DCM PAPI_L2_TCM PAPI_L3_TCM
# 1 1  30000       NF       Copy_E 12251       5748        1021
# 2 2  30000       NF       Copy_E 10928       2553          92
# 3 3  30000       NF       Copy_E 11293       3279         109
# 4 4  30000       NF       Copy_E 10815       2129          90
# 5 5  30000       NF       Copy_E 10929       2309          88
# 6 6  30000       NF       Copy_E 10889       2659          78
#   PAPI_L2_TCA PAPI_L3_TCA PAPI_TOT_INS PAPI_REF_CYC PAPI_L2_TCH PAPI_L1_TCM
# 1 33908       5748        10137937     18757494     14848       27599
# 2 26995       2553         4608640      8406828     21272       23431
# 3 27715       3279         4881007      8938836     22956       23334
# 4 25858       2129         4475231      8191044     22352       23032
# 5 26605       2309         4557176      8288370     22423       22943
# 6 27138       2659         4532534      8247600     22372       23155
#   PAPI_L2_ICH PAPI_L1_ICA PAPI_L1_ICR PAPI_L1_ICH PAPI_L2_DCA PAPI_L3_LDM
# 1  9707       1308350     1308350     1358121     12233       177
# 2 11248        972602      972602     1053554     10854        31
# 3 11449        909846      909846      995347     10833        44
# 4 11343        921478      921478      978220     10917        40
# 5 11327        925420      925420     1011591     10913        42
# 6 11351       1140093     1140093     1218662     11183        33
#   PAPI_DP_OPS PAPI_FP_INS PAPI_VEC_SP PAPI_VEC_DP PAPI_SP_OPS PAPI_L1_ICM
# 1 9           9           0           0           0           18917
# 2 9           9           0           0           0           17189
# 3 9           9           0           0           0           17457
# 4 9           9           0           0           0           16905
# 5 9           9           0           0           0           17372
# 6 9           9           0           0           0           16954
#   PAPI_L2_DCM PAPI_L2_ICM PAPI_L2_LDM PAPI_L2_STM PAPI_L3_DCA PAPI_L3_DCR
# 1 3469        1904        2444        1025        3469        2444
# 2 1036        1002         738         298        1036         738
# 3 1145        1435         897         248        1145         897
# 4  990        1036         724         266         990         724
# 5 1140        1064         853         287        1140         853
# 6 1014        1035         725         289        1014         725
#   PAPI_BR_UCN PAPI_BR_CN PAPI_BR_TKN PAPI_BR_NTK PAPI_BR_INS PAPI_TLB_DM
# 1 8461        1422337    771358      789823      1561181     154
# 2 8147         988979    554319      573302      1127621      52
# 3 8157         939889    531403      552733      1084136      34
# 4 8168         936446    529685      551002      1080687      42
# 5 8188         962314    543074      565022      1108096     279
# 6 8148         938326    531372      551383      1082755      35
#   PAPI_TLB_IM PAPI_TLB_TL PAPI_L1_LDM PAPI_L1_STM PAPI_L2_DCR PAPI_L2_DCW
# 1  63         217         7863        4143        7863        4143
# 2  18          70         6734        4145        6734        4145
# 3  15          49         6695        4126        6695        4126
# 4  12          54         6687        4141        6687        4141
# 5 117         396         7004        4078        7004        4078
# 6  15          50         6683        4155        6683        4155
#   PAPI_BR_MSP PAPI_BR_PRC PAPI_L3_TCW PAPI_L3_DCW PAPI_TOT_IIS PAPI_LD_INS
# 1 1718        1496913     968         968         3506713      859320
# 2 1378         959500     309         309         2764113      736176
# 3 1444         967253     263         263         2424221      709430
# 4 1336         967835     301         301         2505785      708848
# 5 1347         950482     281         281         2999038      804131
# 6 1364         956828     273         273         2595705      716949
#   PAPI_SR_INS PAPI_RES_STL PAPI_LST_INS PAPI_TOT_CYC PAPI_FP_OPS PAPI_L2_TCW
# 1 90063       220165       949383       8222785      142         4162
# 2 88745       138223       824921       6040264       81         4124
# 3 88745       141826       798175       6304764       81         4172
# 4 88756       134477       797604       6138410       81         4179
# 5 88754       139398       892885       5843362       81         4122
# 6 88745       135491       805694       6566140       83         4177
#   PAPI_L3_TCR PAPI_L2_TCR PAPI_L2_ICR PAPI_L3_ICR PAPI_L3_ICA PAPI_L2_ICA
# 1 4619        21541       13665       2041        2041        13665
# 2 2093        19197       12489       1234        1234        12489
# 3 2129        19509       12659       1205        1205        12659
# 4 1931        19087       12390       1112        1112        12390
# 5 2098        19281       12548       1248        1248        12548
# 6 1760        18862       12229       1064        1064        12229

# %%
dfu <- unique(mydata$size.vector)
#dfu[order(dfu)]

comprss <- function(tx) { 
      div <- findInterval(as.numeric(gsub("\\,", "", tx)), 
                          c(1, 1e3, 1e6, 1e9, 1e12) )
      paste(round( as.numeric(gsub("\\,","",tx))/10^(3*(div-1)), 2), 
           c("","K","M","B","T")[div] )}
comprss(dfu[order(dfu)])
# Out:
#  [1] "1 K"   "2 K"   "3 K"   "4 K"   "5 K"   "6 K"   "7 K"   "8 K"   "9 K"
# [10] "10 K"  "20 K"  "30 K"  "40 K"  "50 K"  "60 K"  "70 K"  "80 K"  "90 K"
# [19] "100 K" "200 K" "300 K" "400 K" "500 K" "600 K" "700 K" "800 K" "900 K"
# [28] "1 M"   "2 M"   "3 M"   "4 M"   "5 M"   "6 M"   "7 M"   "8 M"   "9 M"
# [37] "10 M"  "20 M"  "30 M"  "40 M"  "50 M"  "60 M"  "70 M"  "80 M"  "90 M"
# [46] "100 M" "110 M" "120 M" "130 M" "140 M" "150 M" "160 M" "170 M" "180 M"
# [55] "190 M" "200 M"

# %%
#print(new_mydata[,c("PAPI_VEC_SP","PAPI_VEC_DP")])
#print(mydata[,c("PAPI_VEC_SP","PAPI_SP_OPS")])

# %%
div = mydata$PAPI_SP_OPS/mydata$PAPI_VEC_SP
div <- na.omit(div)
subs = mydata$PAPI_BR_INS-(mydata$PAPI_BR_CN + mydata$PAPI_BR_UCN)

# %%
#mean(div)
#quantile(div,0.25)
#quantile(div,0.5)
#quantile(div,0.75)
#boxplot(div)

# %%
#print(mydata[,c("PAPI_BR_INS","PAPI_BR_CN","PAPI_BR_UCN")])#subs = mydata$PAPI_BR_INS-(mydata$PAPI_BR_CN/mydata$PAPI_BR_UCN)
#print(subs)
library('scales')
perc = subs/mydata$PAPI_BR_INS

head(percent(perc[order(perc,decreasing = TRUE)]))
# Out:
# [1] "24.2%" "23.7%" "23.7%" "23.6%" "23.4%" "23.3%"

# %%
#all(new_mydata$PAPI_VEC_SP == new_mydata$PAPI_VEC_DP)
all(mydata$PAPI_DP_SP == mydata$PAPI_SP_OPS)
# Out:
# [1] TRUE

# %%
new_mydata = mydata[,5:61]
new_mydata <- subset(new_mydata, select = -c(PAPI_BR_INS))
new_mydata <- subset(new_mydata, select = -c(PAPI_BR_NTK))
new_mydata <- subset(new_mydata, select = -c(PAPI_BR_PRC))
new_mydata <- subset(new_mydata, select = -c(PAPI_FP_INS))
new_mydata <- subset(new_mydata, select = -c(PAPI_L2_DCA))
new_mydata <- subset(new_mydata, select = -c(PAPI_L2_DCM))
new_mydata <- subset(new_mydata, select = -c(PAPI_L2_DCR))
new_mydata <- subset(new_mydata, select = -c(PAPI_L2_DCW))
new_mydata <- subset(new_mydata, select = -c(PAPI_L3_DCA))
new_mydata <- subset(new_mydata, select = -c(PAPI_L3_DCR))
new_mydata <- subset(new_mydata, select = -c(PAPI_L3_DCW))
new_mydata <- subset(new_mydata, select = -c(PAPI_L3_LDM))
new_mydata <- subset(new_mydata, select = -c(PAPI_LST_INS))
new_mydata <- subset(new_mydata, select = -c(PAPI_RES_STL))
new_mydata <- subset(new_mydata, select = -c(PAPI_TOT_CYC))
new_mydata <- subset(new_mydata, select = -c(PAPI_L1_ICA))
new_mydata <- subset(new_mydata, select = -c(PAPI_L1_ICH))
new_mydata <- subset(new_mydata, select = -c(PAPI_L1_ICM))
new_mydata <- subset(new_mydata, select = -c(PAPI_L1_ICR))
new_mydata <- subset(new_mydata, select = -c(PAPI_L1_TCM))
new_mydata <- subset(new_mydata, select = -c(PAPI_L2_ICA))
new_mydata <- subset(new_mydata, select = -c(PAPI_L2_ICH))
new_mydata <- subset(new_mydata, select = -c(PAPI_L2_ICM))
new_mydata <- subset(new_mydata, select = -c(PAPI_L2_ICR))
new_mydata <- subset(new_mydata, select = -c(PAPI_L2_TCA))
new_mydata <- subset(new_mydata, select = -c(PAPI_L2_TCH))
new_mydata <- subset(new_mydata, select = -c(PAPI_L2_TCM))
new_mydata <- subset(new_mydata, select = -c(PAPI_L2_TCR))
new_mydata <- subset(new_mydata, select = -c(PAPI_L2_TCW))
new_mydata <- subset(new_mydata, select = -c(PAPI_L3_ICA))
new_mydata <- subset(new_mydata, select = -c(PAPI_L3_ICR))
new_mydata <- subset(new_mydata, select = -c(PAPI_L3_TCA))
new_mydata <- subset(new_mydata, select = -c(PAPI_L3_TCR))
new_mydata <- subset(new_mydata, select = -c(PAPI_L3_TCW))
new_mydata <- subset(new_mydata, select = -c(PAPI_TLB_IM))
new_mydata <- subset(new_mydata, select = -c(PAPI_TLB_TL))


new_mydata <- subset(new_mydata, select = -c(PAPI_TOT_IIS))




new_mydata <- subset(new_mydata, select = -c(PAPI_VEC_SP))
new_mydata <- subset(new_mydata, select = -c(PAPI_VEC_DP))
new_mydata <- subset(new_mydata, select = -c(PAPI_DP_OPS))


dim(new_mydata)
# Out:
# [1] 1344000      17

# %%
log.ir <-scale(new_mydata, center = TRUE, scale = TRUE)
res.label <- mydata[,4]
res.pca <- prcomp(log.ir, center = TRUE, scale. = TRUE)

# %%
print(res.pca)
# Out:
# Standard deviations (1, .., p=17):
# Out:
#  [1] 3.572817376 1.343178891 1.029462680 0.811735880 0.482317562 0.474626338
#  [7] 0.373246701 0.243689104 0.164642549 0.137929724 0.070258030 0.048764297
# [13] 0.037210944 0.021890531 0.014800177 0.002536080 0.002189585

# %%
head(unclass(res.pca$rotation)[])
# Out:
#              PC1        PC2         PC3          PC4        PC5
# PAPI_L1_DCM  0.27714690  0.08083900  0.008129582 0.06416348 -0.03711886
# PAPI_L3_TCM  0.23169952  0.35546952  0.256217676 0.07370299 -0.07047240
# PAPI_TOT_INS 0.24377723 -0.26789772 -0.309143510 0.03863404  0.09565467
# PAPI_REF_CYC 0.27873203  0.01645254  0.019081406 0.05774112 -0.10931820
# PAPI_SP_OPS  0.04381301 -0.59083242  0.547150604 0.08877604 -0.24216592
# PAPI_L2_LDM  0.23632902  0.32751797  0.213023834 0.11418717  0.19084071
#              PC6         PC7        PC8          PC9          PC10
# PAPI_L1_DCM  -0.02659736 0.09706293  0.188551545  0.166743562 -0.01491847
# PAPI_L3_TCM   0.07337654 0.11725181 -0.268203813  0.338385444  0.30747405
# PAPI_TOT_INS -0.06126495 0.01387591  0.049537681  0.084193791  0.52295540
# PAPI_REF_CYC  0.03371499 0.04599717  0.009531553  0.169507482 -0.15630453
# PAPI_SP_OPS  -0.16129826 0.11193210  0.003111479 -0.244865892  0.02455723
# PAPI_L2_LDM  -0.19207152 0.34898321 -0.133724064 -0.008515287 -0.09387219
#              PC11        PC12        PC13        PC14       PC15
# PAPI_L1_DCM  -0.10540941 -0.20943323 -0.15411639 -0.3214512 -0.39679032
# PAPI_L3_TCM   0.04284401 -0.15982141  0.02274413 -0.3210167 -0.26544924
# PAPI_TOT_INS  0.13098429  0.64583037 -0.16042472 -0.1041973 -0.06898499
# PAPI_REF_CYC -0.26731938  0.05234532 -0.19485981 -0.3978026  0.76114535
# PAPI_SP_OPS   0.22021707 -0.01037957  0.22946627 -0.2873484 -0.01194922
# PAPI_L2_LDM   0.60070891  0.10843518 -0.05751064  0.2864465  0.22804804
#              PC16         PC17
# PAPI_L1_DCM   0.700253192 -0.086800104
# PAPI_L3_TCM  -0.490820352  0.038534825
# PAPI_TOT_INS  0.003529064 -0.001482334
# PAPI_REF_CYC  0.007361543  0.008281729
# PAPI_SP_OPS   0.001407082 -0.002878945
# PAPI_L2_LDM   0.215548393 -0.012638075

# %%
# Eigenvalues
eig <- (res.pca$sdev)^2
print(eig)
# Out:
#  [1] 1.276502e+01 1.804130e+00 1.059793e+00 6.589151e-01 2.326302e-01
#  [6] 2.252702e-01 1.393131e-01 5.938438e-02 2.710717e-02 1.902461e-02
# [11] 4.936191e-03 2.377957e-03 1.384654e-03 4.791953e-04 2.190452e-04
# [16] 6.431701e-06 4.794284e-06

# %%
# Variances in percentage
variance <- eig*100/sum(eig)
print(variance)
# Out:
#  [1] 7.508838e+01 1.061253e+01 6.234079e+00 3.875971e+00 1.368413e+00
#  [6] 1.325119e+00 8.194888e-01 3.493199e-01 1.594539e-01 1.119095e-01
# [11] 2.903642e-02 1.398798e-02 8.145026e-03 2.818796e-03 1.288501e-03
# [16] 3.783354e-05 2.820167e-05

# %%
# Cumulative variances
cumvar <- cumsum(variance)
print(cumvar)
# Out:
#  [1]  75.08838  85.70090  91.93498  95.81095  97.17937  98.50449  99.32397
#  [8]  99.67329  99.83275  99.94466  99.97369  99.98768  99.99583  99.99865
# [15]  99.99993  99.99997 100.00000

# %%
eig.decathlon2.active <- data.frame(eig = eig, variance = variance,cumvariance = cumvar)
print(eig.decathlon2.active)
# Out:
#             eig     variance cumvariance
# 1  1.276502e+01 7.508838e+01    75.08838
# 2  1.804130e+00 1.061253e+01    85.70090
# 3  1.059793e+00 6.234079e+00    91.93498
# 4  6.589151e-01 3.875971e+00    95.81095
# 5  2.326302e-01 1.368413e+00    97.17937
# 6  2.252702e-01 1.325119e+00    98.50449
# 7  1.393131e-01 8.194888e-01    99.32397
# 8  5.938438e-02 3.493199e-01    99.67329
# 9  2.710717e-02 1.594539e-01    99.83275
# 10 1.902461e-02 1.119095e-01    99.94466
# 11 4.936191e-03 2.903642e-02    99.97369
# 12 2.377957e-03 1.398798e-02    99.98768
# 13 1.384654e-03 8.145026e-03    99.99583
# 14 4.791953e-04 2.818796e-03    99.99865
# 15 2.190452e-04 1.288501e-03    99.99993
# 16 6.431701e-06 3.783354e-05    99.99997
# 17 4.794284e-06 2.820167e-05   100.00000

# %%
summary(res.pca)
# Out:
# Importance of components:
#                           PC1    PC2     PC3     PC4     PC5     PC6     PC7
# Standard deviation     3.5728 1.3432 1.02946 0.81174 0.48232 0.47463 0.37325
# Proportion of Variance 0.7509 0.1061 0.06234 0.03876 0.01368 0.01325 0.00819
# Cumulative Proportion  0.7509 0.8570 0.91935 0.95811 0.97179 0.98504 0.99324
#                            PC8     PC9    PC10    PC11    PC12    PC13    PC14
# Standard deviation     0.24369 0.16464 0.13793 0.07026 0.04876 0.03721 0.02189
# Proportion of Variance 0.00349 0.00159 0.00112 0.00029 0.00014 0.00008 0.00003
# Cumulative Proportion  0.99673 0.99833 0.99945 0.99974 0.99988 0.99996 0.99999
#                           PC15     PC16    PC17
# Standard deviation     0.01480 0.002536 0.00219
# Proportion of Variance 0.00001 0.000000 0.00000
# Cumulative Proportion  1.00000 1.000000 1.00000

# %%
library("factoextra")
eig.val <- get_eigenvalue(res.pca)
head(eig.val)
# Out:
#       eigenvalue variance.percent cumulative.variance.percent
# Dim.1 12.7650240 75.088376        75.08838
# Dim.2  1.8041295 10.612527        85.70090
# Dim.3  1.0597934  6.234079        91.93498
# Dim.4  0.6589151  3.875971        95.81095
# Dim.5  0.2326302  1.368413        97.17937
# Dim.6  0.2252702  1.325119        98.50449

# %%
options(repr.plot.width = 20, repr.plot.height = 10)

# %%
barplot(eig.decathlon2.active[, 2], names.arg=1:nrow(eig.decathlon2.active), 
       main = "Variances",
       xlab = "Principal Components",
       ylab = "Percentage of variances",
       col ="steelblue")
# Add connected line segments to the plot
lines(x = 1:nrow(eig.decathlon2.active), 
      eig.decathlon2.active[, 2], 
      type="b", pch=19, col = "red")
# Out:
# Plot with title "Variances"

# %%
fviz_screeplot(res.pca, ncp=54)
# Out:
# plot without title

# %%
var <- get_pca_var(res.pca)
var
# Out:
# Principal Component Analysis Results for variables
#  ===================================================
#   Name       Description
# 1 "$coord"   "Coordinates for the variables"
# 2 "$cor"     "Correlations between variables and dimensions"
# 3 "$cos2"    "Cos2 for the variables"
# 4 "$contrib" "contributions of the variables"

# %%
var$coord
# Out:
#              Dim.1     Dim.2       Dim.3        Dim.4        Dim.5
# PAPI_L1_DCM  0.9901952  0.10858124  0.008369101  0.052083800 -0.0179030758
# PAPI_L3_TCM  0.8278201  0.47745915  0.263766535  0.059827365 -0.0339900756
# PAPI_TOT_INS 0.8709715 -0.35983457 -0.318251706  0.031360634  0.0461359258
# PAPI_REF_CYC 0.9958587  0.02209870  0.019643595  0.046870541 -0.0527260855
# PAPI_SP_OPS  0.1565359 -0.79359363  0.563271127  0.072062696 -0.1168008748
# PAPI_L2_LDM  0.8443604  0.43991522  0.219300087  0.092689824  0.0920458269
# PAPI_L2_STM  0.8895820  0.38999642  0.103619673  0.062128408  0.0149736171
# PAPI_BR_UCN  0.6277515 -0.11610447  0.131119966 -0.745696061  0.0755533816
# PAPI_BR_CN   0.9585720 -0.15804050  0.125956161  0.034891177 -0.1412721673
# PAPI_BR_TKN  0.9588549 -0.15581235  0.125518657  0.036367669 -0.1412137142
# PAPI_TLB_DM  0.8524031  0.26544622  0.021767385 -0.218865171 -0.0959453175
# PAPI_L1_LDM  0.9631328 -0.10307491  0.026345354  0.085336438  0.0703872542
# PAPI_L1_STM  0.9255283  0.09978434 -0.313732713  0.011371838  0.0006596543
# PAPI_BR_MSP  0.9857772  0.11416356  0.026315170  0.058486179  0.0177604788
# PAPI_LD_INS  0.7959142 -0.34782130 -0.477484999  0.015574274  0.0574530268
# PAPI_SR_INS  0.9024893 -0.23106347 -0.278949752  0.008017429 -0.1372189287
# PAPI_FP_OPS  0.8107065 -0.34323286  0.239730711  0.118973587  0.3488461811
#              Dim.6       Dim.7        Dim.8         Dim.9        Dim.10
# PAPI_L1_DCM  -0.01262381  0.036228418  0.0459479569  0.027453085 -0.0020577004
# PAPI_L3_TCM   0.03482644  0.043763852 -0.0653583467  0.055712642  0.0424098105
# PAPI_TOT_INS -0.02907796  0.005179138  0.0120717930  0.013861880  0.0721310942
# PAPI_REF_CYC  0.01600202  0.017168290  0.0023227357  0.027908144 -0.0215590400
# PAPI_SP_OPS  -0.07655640  0.041778288  0.0007582334 -0.040315345  0.0033871720
# PAPI_L2_LDM  -0.09116220  0.130256830 -0.0325870972 -0.001401979 -0.0129477656
# PAPI_L2_STM   0.15484892 -0.025417072 -0.0198165797 -0.119618680  0.0465284785
# PAPI_BR_UCN   0.08574374  0.078151995  0.0045738749  0.001918813 -0.0003411438
# PAPI_BR_CN    0.11436345 -0.060933791  0.0358061018  0.028859648  0.0103601094
# PAPI_BR_TKN   0.11508221 -0.060721833  0.0361640770  0.028966824  0.0109044651
# PAPI_TLB_DM  -0.31082173 -0.219387870 -0.0181573798 -0.016951833  0.0022728528
# PAPI_L1_LDM  -2.625150e-03 -9.581099e-04  7.902045e-05
# PAPI_L1_STM  -1.290270e-03 -5.913551e-04  4.111074e-05
# PAPI_BR_MSP  -1.056626e-03  8.095838e-06  9.311371e-06
# PAPI_LD_INS   2.842975e-03 -9.268016e-06  5.320718e-06
# PAPI_SR_INS  -3.153436e-03  4.034473e-07 -3.301288e-06
# PAPI_FP_OPS  -6.308058e-04  1.754724e-06 -9.130359e-07

# %%
library(devtools)
library(ggbiplot)
g <- ggbiplot(res.pca, obs.scale = 1, var.scale = 1, groups = res.label, ellipse = TRUE, circle = TRUE)
g <- g + scale_color_discrete(name = '')
g <- g + theme(legend.direction = 'horizontal', legend.position = 'top')
print(g)
# Out:
# plot without title

# %%
# Helper function : 
# Correlation between variables and principal components
var_cor_func <- function(var.loadings, comp.sdev){
  var.loadings*comp.sdev
  }

# Variable correlation/coordinates
loadings <- res.pca$rotation
sdev <- res.pca$sdev

var.coord <- var.cor <- t(apply(loadings, 1, var_cor_func, sdev))
print(var.coord[, 1:4])
# Out:
#                    PC1         PC2          PC3          PC4
# PAPI_L1_DCM  0.9901952  0.10858124  0.008369101  0.052083800
# PAPI_L3_TCM  0.8278201  0.47745915  0.263766535  0.059827365
# PAPI_TOT_INS 0.8709715 -0.35983457 -0.318251706  0.031360634
# PAPI_REF_CYC 0.9958587  0.02209870  0.019643595  0.046870541
# PAPI_SP_OPS  0.1565359 -0.79359363  0.563271127  0.072062696
# PAPI_L2_LDM  0.8443604  0.43991522  0.219300087  0.092689824
# PAPI_L2_STM  0.8895820  0.38999642  0.103619673  0.062128408
# PAPI_BR_UCN  0.6277515 -0.11610447  0.131119966 -0.745696061
# PAPI_BR_CN   0.9585720 -0.15804050  0.125956161  0.034891177
# PAPI_BR_TKN  0.9588549 -0.15581235  0.125518657  0.036367669
# PAPI_TLB_DM  0.8524031  0.26544622  0.021767385 -0.218865171
# PAPI_L1_LDM  0.9631328 -0.10307491  0.026345354  0.085336438
# PAPI_L1_STM  0.9255283  0.09978434 -0.313732713  0.011371838
# PAPI_BR_MSP  0.9857772  0.11416356  0.026315170  0.058486179
# PAPI_LD_INS  0.7959142 -0.34782130 -0.477484999  0.015574274
# PAPI_SR_INS  0.9024893 -0.23106347 -0.278949752  0.008017429
# PAPI_FP_OPS  0.8107065 -0.34323286  0.239730711  0.118973587

# %%
var.cos2 <- var.coord^2
print(var.cos2)
# Out:
#                     PC1          PC2          PC3          PC4          PC5
# PAPI_L1_DCM  0.98048662 0.0117898862 7.004185e-05 2.712722e-03 3.205201e-04
# PAPI_L3_TCM  0.68528608 0.2279672428 6.957279e-02 3.579314e-03 1.155325e-03
# PAPI_TOT_INS 0.75859139 0.1294809143 1.012841e-01 9.834894e-04 2.128524e-03
# PAPI_REF_CYC 0.99173446 0.0004883525 3.858708e-04 2.196848e-03 2.780040e-03
# PAPI_SP_OPS  0.02450348 0.6297908524 3.172744e-01 5.193032e-03 1.364244e-02
# PAPI_L2_LDM  0.71294454 0.1935253992 4.809253e-02 8.591404e-03 8.472434e-03
#     6.710544     6.380615     6.199409     5.942734     5.692046     5.585141
#  PAPI_L3_TCM  PAPI_FP_OPS  PAPI_LD_INS  PAPI_BR_UCN  PAPI_SP_OPS
#     5.368467     5.148796     4.962619     3.087122     0.191958

# %%
print(sort(var.contrib[,'PC2'],decreasing=TRUE))
# Out:
#  PAPI_SP_OPS  PAPI_L3_TCM  PAPI_L2_LDM  PAPI_L2_STM PAPI_TOT_INS  PAPI_LD_INS
#  34.90829461  12.63585783  10.72680180   8.43050359   7.17691895   6.70570794
#  PAPI_FP_OPS  PAPI_TLB_DM  PAPI_SR_INS   PAPI_BR_CN  PAPI_BR_TKN  PAPI_BR_UCN
#   6.52995229   3.90557854   2.95934005   1.38442381   1.34566213   0.74718843
#  PAPI_BR_MSP  PAPI_L1_DCM  PAPI_L1_LDM  PAPI_L1_STM PAPI_REF_CYC
#   0.72241583   0.65349444   0.58889546   0.55189572   0.02706859

# %%
print(sort(var.contrib[,'PC3'],decreasing=TRUE))
# Out:
#  PAPI_SP_OPS  PAPI_LD_INS PAPI_TOT_INS  PAPI_L1_STM  PAPI_SR_INS  PAPI_L3_TCM
#  29.93737838  21.51286492   9.55697099   9.28749075   7.34227666   6.56474974
#  PAPI_FP_OPS  PAPI_L2_LDM  PAPI_BR_UCN   PAPI_BR_CN  PAPI_BR_TKN  PAPI_L2_STM
#   5.42283177   4.53791536   1.62224500   1.49698558   1.48660418   1.01312544
#  PAPI_L1_LDM  PAPI_BR_MSP  PAPI_TLB_DM PAPI_REF_CYC  PAPI_L1_DCM
#   0.06549179   0.06534181   0.04470862   0.03641000   0.00660901

# %%
fviz_pca_var(res.pca, col.var="contrib") + scale_color_gradient2(low="white", mid="blue", high="red", midpoint=50) + theme_minimal()
# Out:
# plot without title

# %%
new_mydata1 = mydata[,5:61]
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_BR_INS))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_BR_NTK))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_BR_PRC))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_FP_INS))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L2_DCA))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L2_DCM))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L2_DCR))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L2_DCW))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L3_DCA))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L3_DCR))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L3_DCW))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L3_LDM))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_LST_INS))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_RES_STL))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_TOT_CYC))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L1_ICA))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L1_ICH))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L1_ICM))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L1_ICR))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L1_TCM))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L2_ICA))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L2_ICH))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L2_ICM))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L2_ICR))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L2_TCA))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L2_TCH))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L2_TCM))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L2_TCR))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L2_TCW))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L3_ICA))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L3_ICR))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L3_TCA))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L3_TCR))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L3_TCW))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_TLB_IM))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_TLB_TL))



new_mydata1 <- subset(new_mydata1, select = -c(PAPI_TOT_IIS))




new_mydata1 <- subset(new_mydata1, select = -c(PAPI_VEC_SP))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_VEC_DP))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_DP_OPS))

my_data_ordered1 <- new_mydata1[,order(colnames(new_mydata1))]


options(repr.matrix.max.rows = 100)
options(repr.matrix.max.cols = 100)
res1 <- cor(my_data_ordered1)
dim(res1)
round(res1, 2)
# Out:
# [1] 17 17
#              PAPI_BR_CN PAPI_BR_MSP PAPI_BR_TKN PAPI_BR_UCN PAPI_FP_OPS
# PAPI_BR_CN   1.00       0.92        1.00        0.61        0.83
# PAPI_BR_MSP  0.92       1.00        0.92        0.57        0.77
# PAPI_BR_TKN  1.00       0.92        1.00        0.60        0.83
# PAPI_BR_UCN  0.61       0.57        0.60        1.00        0.51
# PAPI_FP_OPS  0.83       0.77        0.83        0.51        1.00
# PAPI_L1_DCM  0.94       1.00        0.94        0.57        0.76
# PAPI_L1_LDM  0.91       0.96        0.91        0.56        0.82
# PAPI_L1_STM  0.85       0.91        0.85        0.53        0.66
# PAPI_L2_LDM  0.74       0.91        0.74        0.45        0.61
# PAPI_L2_STM  0.82       0.91        0.82        0.49        0.64
# PAPI_L3_TCM  0.76       0.88        0.76        0.46        0.56
# PAPI_LD_INS  0.74       0.74        0.74        0.47        0.66
# PAPI_REF_CYC 0.96       0.99        0.96        0.59        0.79
# PAPI_SP_OPS  0.35       0.09        0.35        0.20        0.49
# PAPI_SR_INS  0.88       0.85        0.88        0.55        0.70
# PAPI_TLB_DM  0.76       0.86        0.76        0.62        0.56
# PAPI_TOT_INS 0.84       0.81        0.84        0.52        0.77
#              PAPI_L1_DCM PAPI_L1_LDM PAPI_L1_STM PAPI_L2_LDM PAPI_L2_STM
# PAPI_BR_CN   0.94        0.91         0.85        0.74        0.82
# PAPI_BR_MSP  1.00        0.96         0.91        0.91        0.91
# PAPI_BR_TKN  0.94        0.91         0.85        0.74        0.82
# PAPI_BR_UCN  0.57        0.56         0.53        0.45        0.49
# PAPI_FP_OPS  0.76        0.82         0.66        0.61        0.64
# PAPI_L1_DCM  1.00        0.96         0.92        0.89        0.92
# PAPI_L1_LDM  0.96        1.00         0.86        0.81        0.80
# PAPI_L1_STM  0.92        0.86         1.00        0.74        0.85
# PAPI_L2_LDM  0.89        0.81         0.74        1.00        0.93
# PAPI_L2_STM  0.92        0.80         0.85        0.93        1.00
# PAPI_L3_TCM  0.88        0.75         0.72        0.97        0.95
# PAPI_LD_INS  0.75        0.81         0.83        0.44        0.51
# PAPI_REF_CYC 0.99        0.96         0.92        0.85        0.90
# PAPI_SP_OPS  0.08        0.26        -0.12       -0.08       -0.12
# PAPI_SR_INS  0.86        0.86         0.89        0.59        0.69
# PAPI_TLB_DM  0.86        0.79         0.78        0.81        0.81
# PAPI_TOT_INS 0.82        0.88         0.86        0.52        0.60
#              PAPI_L3_TCM PAPI_LD_INS PAPI_REF_CYC PAPI_SP_OPS PAPI_SR_INS
# PAPI_BR_CN    0.76       0.74        0.96          0.35       0.88
# PAPI_BR_MSP   0.88       0.74        0.99          0.09       0.85
# PAPI_BR_TKN   0.76       0.74        0.96          0.35       0.88
# PAPI_BR_UCN   0.46       0.47        0.59          0.20       0.55
# PAPI_FP_OPS   0.56       0.66        0.79          0.49       0.70
# PAPI_L1_DCM   0.88       0.75        0.99          0.08       0.86
# PAPI_L1_LDM   0.75       0.81        0.96          0.26       0.86
# PAPI_L1_STM   0.72       0.83        0.92         -0.12       0.89
# PAPI_L2_LDM   0.97       0.44        0.85         -0.08       0.59
# PAPI_L2_STM   0.95       0.51        0.90         -0.12       0.69
# PAPI_L3_TCM   1.00       0.37        0.85         -0.10       0.58
# PAPI_LD_INS   0.37       1.00        0.77          0.14       0.92
# PAPI_REF_CYC  0.85       0.77        1.00          0.16       0.90
# PAPI_SP_OPS  -0.10       0.14        0.16          1.00       0.18
# PAPI_SR_INS   0.58       0.92        0.90          0.18       1.00
# PAPI_TLB_DM   0.81       0.58        0.84         -0.05       0.69
# PAPI_TOT_INS  0.47       0.98        0.85          0.24       0.94
#              PAPI_TLB_DM PAPI_TOT_INS
# PAPI_BR_CN    0.76       0.84
# PAPI_BR_MSP   0.86       0.81
# PAPI_BR_TKN   0.76       0.84
# PAPI_BR_UCN   0.62       0.52
# PAPI_FP_OPS   0.56       0.77
# PAPI_L1_DCM   0.86       0.82
# PAPI_L1_LDM   0.79       0.88
# PAPI_L1_STM   0.78       0.86
# PAPI_L2_LDM   0.81       0.52
# PAPI_L2_STM   0.81       0.60
# PAPI_L3_TCM   0.81       0.47
# PAPI_LD_INS   0.58       0.98
# PAPI_REF_CYC  0.84       0.85
# PAPI_SP_OPS  -0.05       0.24
# PAPI_SR_INS   0.69       0.94
# PAPI_TLB_DM   1.00       0.64
# PAPI_TOT_INS  0.64       1.00

# %%
library(corrplot)


corrplot(res1, tl.col = "black", tl.srt = 90, tl.cex = 1, method= "square", order = "AOE", number.cex = 0.5)
# Out:
# Plot with title ""

# %%
corrplot(res1, tl.col = "black", tl.srt = 90, tl.cex = 1, method= "square", order = "hclust", number.cex = 0.5, addrect=2)
# Out:
# Plot with title ""

# %%
corrplot(res1, tl.col = "black", tl.srt = 90, tl.cex = 1, method= "square", order = "hclust", number.cex = 0.5, addrect=3)
# Out:
# Plot with title ""

# %%
corrplot(res1, tl.col = "black", tl.srt = 90, tl.cex = 1, method= "square", order = "hclust", number.cex = 0.5, addrect=4)
# Out:
# Plot with title ""

# %%
corrplot(res1, tl.col = "black", tl.srt = 90, tl.cex = 1, method= "square", order = "hclust", number.cex = 0.5, addrect=5)
# Out:
# Plot with title ""

# %%
corrplot(res1, tl.col = "black", tl.srt = 90, tl.cex = 1, method= "square", order = "hclust", number.cex = 0.5, addrect=6)
# Out:
# Plot with title ""

# %%
corrplot(res1, tl.col = "black", tl.srt = 90, tl.cex = 1, method= "square", order = "hclust", number.cex = 0.5, addrect=7)
# Out:
# Plot with title ""

# %%
corrplot(res1, tl.col = "black", tl.srt = 90, tl.cex = 1, method= "square", order = "hclust", number.cex = 0.5, addrect=8)
# Out:
# Plot with title ""

# %%
corrplot(res1, tl.col = "black", tl.srt = 90, tl.cex = 1, method= "square", order = "hclust", number.cex = 0.5, addrect=9)
# Out:
# Plot with title ""

# %%
corrplot(res1, tl.col = "black", tl.srt = 90, tl.cex = 1, method= "square", order = "hclust", number.cex = 0.5, addrect=10)
# Out:
# Plot with title ""

# %%
corrplot(res1, tl.col = "black", tl.srt = 90, tl.cex = 1, method= "square", order = "hclust", number.cex = 0.5, addrect=11)
# Out:
# Plot with title ""

# %%
corrplot(res1, tl.col = "black", tl.srt = 90, tl.cex = 1, method= "square", order = "hclust", number.cex = 0.5, addrect=12)
# Out:
# Plot with title ""

# %%
corrplot(res1, tl.col = "black", tl.srt = 90, tl.cex = 1, method= "square", order = "hclust", number.cex = 0.5, addrect=13)
# Out:
# Plot with title ""

# %%
corrplot(res1, tl.col = "black", tl.srt = 90, tl.cex = 1, method= "square", order = "hclust", number.cex = 0.5, addrect=14)
# Out:
# Plot with title ""

# %%
corrplot(res1, tl.col = "black", tl.srt = 90, tl.cex = 1, method= "square", order = "hclust", number.cex = 0.5, addrect=15)
# Out:
# Plot with title ""

# %%
corrplot(res1, tl.col = "black", tl.srt = 90, tl.cex = 1, method= "square", order = "hclust", number.cex = 0.5, addrect=16)
# Out:
# Plot with title ""

# %%
corrplot(res1, tl.col = "black", tl.srt = 90, tl.cex = 1, method= "square", order = "FPC", number.cex = 0.5)
# Out:
# Plot with title ""

# %%
corrplot(res1, tl.col = "black", tl.srt = 90, tl.cex = 1, method= "square", order = "alphabet", number.cex = 0.5)
# Out:
# Plot with title ""
