# %%
library("factoextra")
options(repr.plot.width=12, repr.plot.height=13)

# %%
path="C:/Users/Jordi/"
setwd(path)
mydata = read.csv("data-all.csv", sep=";")

# %%
head(mydata)
# Out:
#   id size.vector comp.opt label  PAPI_L1_DCM PAPI_L2_TCM PAPI_L3_TCM
# 1 1  30000       NF       Copy_E 12251       5748        1021
# 2 2  30000       NF       Copy_E 10928       2553          92
# 3 3  30000       NF       Copy_E 11293       3279         109
# 4 4  30000       NF       Copy_E 10815       2129          90
# 5 5  30000       NF       Copy_E 10929       2309          88
# 6 6  30000       NF       Copy_E 10889       2659          78
#   PAPI_L2_TCA PAPI_L3_TCA PAPI_TOT_INS PAPI_REF_CYC PAPI_L2_TCH PAPI_L1_TCM
# 1 33908       5748        10137937     18757494     14848       27599
# 2 26995       2553         4608640      8406828     21272       23431
# 3 27715       3279         4881007      8938836     22956       23334
# 4 25858       2129         4475231      8191044     22352       23032
# 5 26605       2309         4557176      8288370     22423       22943
# 6 27138       2659         4532534      8247600     22372       23155
#   PAPI_L2_ICH PAPI_L1_ICA PAPI_L1_ICR PAPI_L1_ICH PAPI_L2_DCA PAPI_L3_LDM
# 1  9707       1308350     1308350     1358121     12233       177
# 2 11248        972602      972602     1053554     10854        31
# 3 11449        909846      909846      995347     10833        44
# 4 11343        921478      921478      978220     10917        40
# 5 11327        925420      925420     1011591     10913        42
# 6 11351       1140093     1140093     1218662     11183        33
#   PAPI_DP_OPS PAPI_FP_INS PAPI_VEC_SP PAPI_VEC_DP PAPI_SP_OPS PAPI_L1_ICM
# 1 9           9           0           0           0           18917
# 2 9           9           0           0           0           17189
# 3 9           9           0           0           0           17457
# 4 9           9           0           0           0           16905
# 5 9           9           0           0           0           17372
# 6 9           9           0           0           0           16954
#   PAPI_L2_DCM PAPI_L2_ICM PAPI_L2_LDM PAPI_L2_STM PAPI_L3_DCA PAPI_L3_DCR
# 1 3469        1904        2444        1025        3469        2444
# 2 1036        1002         738         298        1036         738
# 3 1145        1435         897         248        1145         897
# 4  990        1036         724         266         990         724
# 5 1140        1064         853         287        1140         853
# 6 1014        1035         725         289        1014         725
#   PAPI_BR_UCN PAPI_BR_CN PAPI_BR_TKN PAPI_BR_NTK PAPI_BR_INS PAPI_TLB_DM
# 1 8461        1422337    771358      789823      1561181     154
# 2 8147         988979    554319      573302      1127621      52
# 3 8157         939889    531403      552733      1084136      34
# 4 8168         936446    529685      551002      1080687      42
# 5 8188         962314    543074      565022      1108096     279
# 6 8148         938326    531372      551383      1082755      35
#   PAPI_TLB_IM PAPI_TLB_TL PAPI_L1_LDM PAPI_L1_STM PAPI_L2_DCR PAPI_L2_DCW
# 1  63         217         7863        4143        7863        4143
# 2  18          70         6734        4145        6734        4145
# 3  15          49         6695        4126        6695        4126
# 4  12          54         6687        4141        6687        4141
# 5 117         396         7004        4078        7004        4078
# 6  15          50         6683        4155        6683        4155
#   PAPI_BR_MSP PAPI_BR_PRC PAPI_L3_TCW PAPI_L3_DCW PAPI_TOT_IIS PAPI_LD_INS
# 1 1718        1496913     968         968         3506713      859320
# 2 1378         959500     309         309         2764113      736176
# 3 1444         967253     263         263         2424221      709430
# 4 1336         967835     301         301         2505785      708848
# 5 1347         950482     281         281         2999038      804131
# 6 1364         956828     273         273         2595705      716949
#   PAPI_SR_INS PAPI_RES_STL PAPI_LST_INS PAPI_TOT_CYC PAPI_FP_OPS PAPI_L2_TCW
# 1 90063       220165       949383       8222785      142         4162
# 2 88745       138223       824921       6040264       81         4124
# 3 88745       141826       798175       6304764       81         4172
# 4 88756       134477       797604       6138410       81         4179
# 5 88754       139398       892885       5843362       81         4122
# 6 88745       135491       805694       6566140       83         4177
#   PAPI_L3_TCR PAPI_L2_TCR PAPI_L2_ICR PAPI_L3_ICR PAPI_L3_ICA PAPI_L2_ICA
# 1 4619        21541       13665       2041        2041        13665
# 2 2093        19197       12489       1234        1234        12489
# 3 2129        19509       12659       1205        1205        12659
# 4 1931        19087       12390       1112        1112        12390
# 5 2098        19281       12548       1248        1248        12548
# 6 1760        18862       12229       1064        1064        12229

# %%
dfu <- unique(mydata$size.vector)
#dfu[order(dfu)]

comprss <- function(tx) { 
      div <- findInterval(as.numeric(gsub("\\,", "", tx)), 
                          c(1, 1e3, 1e6, 1e9, 1e12) )
      paste(round( as.numeric(gsub("\\,","",tx))/10^(3*(div-1)), 2), 
           c("","K","M","B","T")[div] )}
comprss(dfu[order(dfu)])
# Out:
#  [1] "1 K"   "2 K"   "3 K"   "4 K"   "5 K"   "6 K"   "7 K"   "8 K"   "9 K"
# [10] "10 K"  "20 K"  "30 K"  "40 K"  "50 K"  "60 K"  "70 K"  "80 K"  "90 K"
# [19] "100 K" "200 K" "300 K" "400 K" "500 K" "600 K" "700 K" "800 K" "900 K"
# [28] "1 M"   "2 M"   "3 M"   "4 M"   "5 M"   "6 M"   "7 M"   "8 M"   "9 M"
# [37] "10 M"  "20 M"  "30 M"  "40 M"  "50 M"  "60 M"  "70 M"  "80 M"  "90 M"
# [46] "100 M" "110 M" "120 M" "130 M" "140 M" "150 M" "160 M" "170 M" "180 M"
# [55] "190 M" "200 M"

# %%
#print(new_mydata[,c("PAPI_VEC_SP","PAPI_VEC_DP")])
#print(mydata[,c("PAPI_VEC_SP","PAPI_SP_OPS")])

# %%
div = mydata$PAPI_SP_OPS/mydata$PAPI_VEC_SP
div <- na.omit(div)
subs = mydata$PAPI_BR_INS-(mydata$PAPI_BR_CN + mydata$PAPI_BR_UCN)

# %%
#mean(div)
#quantile(div,0.25)
#quantile(div,0.5)
#quantile(div,0.75)
#boxplot(div)

# %%
#print(mydata[,c("PAPI_BR_INS","PAPI_BR_CN","PAPI_BR_UCN")])#subs = mydata$PAPI_BR_INS-(mydata$PAPI_BR_CN/mydata$PAPI_BR_UCN)
#print(subs)
library('scales')
perc = subs/mydata$PAPI_BR_INS

head(percent(perc[order(perc,decreasing = TRUE)]))
# Out:
# [1] "24.2%" "23.7%" "23.7%" "23.6%" "23.4%" "23.3%"

# %%
#all(new_mydata$PAPI_VEC_SP == new_mydata$PAPI_VEC_DP)
all(mydata$PAPI_DP_SP == mydata$PAPI_SP_OPS)
# Out:
# [1] TRUE

# %%
new_mydata = mydata[,5:61]
new_mydata <- subset(new_mydata, select = -c(PAPI_BR_INS))
new_mydata <- subset(new_mydata, select = -c(PAPI_BR_NTK))
new_mydata <- subset(new_mydata, select = -c(PAPI_BR_PRC))
new_mydata <- subset(new_mydata, select = -c(PAPI_FP_INS))
new_mydata <- subset(new_mydata, select = -c(PAPI_L2_DCA))
new_mydata <- subset(new_mydata, select = -c(PAPI_L2_DCM))
new_mydata <- subset(new_mydata, select = -c(PAPI_L2_DCR))
new_mydata <- subset(new_mydata, select = -c(PAPI_L2_DCW))
new_mydata <- subset(new_mydata, select = -c(PAPI_L3_DCA))
new_mydata <- subset(new_mydata, select = -c(PAPI_L3_DCR))
new_mydata <- subset(new_mydata, select = -c(PAPI_L3_DCW))
new_mydata <- subset(new_mydata, select = -c(PAPI_L3_LDM))
new_mydata <- subset(new_mydata, select = -c(PAPI_LST_INS))
new_mydata <- subset(new_mydata, select = -c(PAPI_RES_STL))
new_mydata <- subset(new_mydata, select = -c(PAPI_TOT_CYC))
new_mydata <- subset(new_mydata, select = -c(PAPI_L1_ICA))
new_mydata <- subset(new_mydata, select = -c(PAPI_L1_ICH))
new_mydata <- subset(new_mydata, select = -c(PAPI_L1_ICM))
new_mydata <- subset(new_mydata, select = -c(PAPI_L1_ICR))
new_mydata <- subset(new_mydata, select = -c(PAPI_L1_TCM))
new_mydata <- subset(new_mydata, select = -c(PAPI_L2_ICA))
new_mydata <- subset(new_mydata, select = -c(PAPI_L2_ICH))
new_mydata <- subset(new_mydata, select = -c(PAPI_L2_ICM))
new_mydata <- subset(new_mydata, select = -c(PAPI_L2_ICR))
new_mydata <- subset(new_mydata, select = -c(PAPI_L2_TCA))
new_mydata <- subset(new_mydata, select = -c(PAPI_L2_TCH))
new_mydata <- subset(new_mydata, select = -c(PAPI_L2_TCM))
new_mydata <- subset(new_mydata, select = -c(PAPI_L2_TCR))
new_mydata <- subset(new_mydata, select = -c(PAPI_L2_TCW))
new_mydata <- subset(new_mydata, select = -c(PAPI_L3_ICA))
new_mydata <- subset(new_mydata, select = -c(PAPI_L3_ICR))
new_mydata <- subset(new_mydata, select = -c(PAPI_L3_TCA))
new_mydata <- subset(new_mydata, select = -c(PAPI_L3_TCR))
new_mydata <- subset(new_mydata, select = -c(PAPI_L3_TCW))
new_mydata <- subset(new_mydata, select = -c(PAPI_TLB_IM))
new_mydata <- subset(new_mydata, select = -c(PAPI_TLB_TL))


new_mydata <- subset(new_mydata, select = -c(PAPI_BR_UCN))
new_mydata <- subset(new_mydata, select = -c(PAPI_TOT_IIS))




new_mydata <- subset(new_mydata, select = -c(PAPI_VEC_SP))
new_mydata <- subset(new_mydata, select = -c(PAPI_VEC_DP))
new_mydata <- subset(new_mydata, select = -c(PAPI_DP_OPS))


dim(new_mydata)
# Out:
# [1] 1344000      16

# %%
log.ir <-scale(new_mydata, center = TRUE, scale = TRUE)
res.label <- mydata[,4]
res.pca <- prcomp(log.ir, center = TRUE, scale. = TRUE)

# %%
print(res.pca)
# PAPI_TOT_INS 0.24751370 -0.27552445 -0.29997690 -0.0462709983 -0.10777365
# PAPI_REF_CYC 0.28321648  0.01152619  0.02652924  0.0261158968  0.10339364
# PAPI_SP_OPS  0.04280286 -0.58936072  0.56109681  0.2357565936  0.05461413
# PAPI_L2_LDM  0.24094581  0.32412184  0.22020178 -0.1133312568 -0.25464123
#              PC6         PC7          PC8         PC9         PC10
# PAPI_L1_DCM  -0.11805072  0.188341925  0.16612961 -0.01454724  0.10537800
# PAPI_L3_TCM  -0.11487735 -0.269106057  0.33791996  0.30807117 -0.04296873
# PAPI_TOT_INS -0.01941848  0.049914436  0.08362999  0.52298543 -0.13035333
# PAPI_REF_CYC -0.06525651  0.010568567  0.17042127 -0.15619623  0.26760503
# PAPI_SP_OPS  -0.18274396  0.003438655 -0.24411493  0.02396911 -0.21997255
# PAPI_L2_LDM  -0.35400238 -0.139671509 -0.01091547 -0.09332335 -0.60104761
#              PC11        PC12        PC13       PC14        PC15
# PAPI_L1_DCM  -0.20896158 -0.15534916 -0.3211275 -0.39682466  0.687602815
# PAPI_L3_TCM  -0.15968540  0.02164436 -0.3209002 -0.26548868 -0.484651254
# PAPI_TOT_INS  0.64641530 -0.15947034 -0.1032069 -0.06900645  0.003168330
# PAPI_REF_CYC  0.05294781 -0.19572403 -0.3970899  0.76109421  0.007739349
# PAPI_SP_OPS  -0.01023635  0.22806472 -0.2884329 -0.01196902  0.001022849
# PAPI_L2_LDM   0.10840237 -0.05643616  0.2866805  0.22807789  0.213337710
#              PC16
# PAPI_L1_DCM   0.157917811
# PAPI_L3_TCM  -0.087281345
# PAPI_TOT_INS  0.002359405
# PAPI_REF_CYC -0.006343409
# PAPI_SP_OPS   0.003241254
# PAPI_L2_LDM   0.033888282

# %%
# Eigenvalues
eig <- (res.pca$sdev)^2
print(eig)
# Out:
#  [1] 1.239035e+01 1.795076e+00 1.052580e+00 2.608858e-01 2.291171e-01
#  [6] 1.568384e-01 5.953659e-02 2.717366e-02 1.902766e-02 4.938005e-03
# [11] 2.379400e-03 1.387998e-03 4.814508e-04 2.190456e-04 6.475021e-06
# [16] 5.262199e-06

# %%
# Variances in percentage
variance <- eig*100/sum(eig)
print(variance)
# Out:
#  [1] 7.743967e+01 1.121922e+01 6.578627e+00 1.630536e+00 1.431982e+00
#  [6] 9.802397e-01 3.721037e-01 1.698354e-01 1.189229e-01 3.086253e-02
# [11] 1.487125e-02 8.674988e-03 3.009068e-03 1.369035e-03 4.046888e-05
# [16] 3.288875e-05

# %%
# Cumulative variances
cumvar <- cumsum(variance)
print(cumvar)
# Out:
#  [1]  77.43967  88.65889  95.23752  96.86806  98.30004  99.28028  99.65238
#  [8]  99.82222  99.94114  99.97200  99.98687  99.99555  99.99856  99.99993
# [15]  99.99997 100.00000

# %%
eig.decathlon2.active <- data.frame(eig = eig, variance = variance,cumvariance = cumvar)
print(eig.decathlon2.active)
# Out:
#             eig     variance cumvariance
# 1  1.239035e+01 7.743967e+01    77.43967
# 2  1.795076e+00 1.121922e+01    88.65889
# 3  1.052580e+00 6.578627e+00    95.23752
# 4  2.608858e-01 1.630536e+00    96.86806
# 5  2.291171e-01 1.431982e+00    98.30004
# 6  1.568384e-01 9.802397e-01    99.28028
# 7  5.953659e-02 3.721037e-01    99.65238
# 8  2.717366e-02 1.698354e-01    99.82222
# 9  1.902766e-02 1.189229e-01    99.94114
# 10 4.938005e-03 3.086253e-02    99.97200
# 11 2.379400e-03 1.487125e-02    99.98687
# 12 1.387998e-03 8.674988e-03    99.99555
# 13 4.814508e-04 3.009068e-03    99.99856
# 14 2.190456e-04 1.369035e-03    99.99993
# 15 6.475021e-06 4.046888e-05    99.99997
# 16 5.262199e-06 3.288875e-05   100.00000

# %%
summary(res.pca)
# Out:
# Importance of components:
#                           PC1    PC2     PC3     PC4     PC5    PC6     PC7
# Standard deviation     3.5200 1.3398 1.02595 0.51077 0.47866 0.3960 0.24400
# Proportion of Variance 0.7744 0.1122 0.06579 0.01631 0.01432 0.0098 0.00372
# Cumulative Proportion  0.7744 0.8866 0.95238 0.96868 0.98300 0.9928 0.99652
#                           PC8     PC9    PC10    PC11    PC12    PC13    PC14
# Standard deviation     0.1648 0.13794 0.07027 0.04878 0.03726 0.02194 0.01480
# Proportion of Variance 0.0017 0.00119 0.00031 0.00015 0.00009 0.00003 0.00001
# Cumulative Proportion  0.9982 0.99941 0.99972 0.99987 0.99996 0.99999 1.00000
#                            PC15     PC16
# Standard deviation     0.002545 0.002294
# Proportion of Variance 0.000000 0.000000
# Cumulative Proportion  1.000000 1.000000

# %%
library("factoextra")
eig.val <- get_eigenvalue(res.pca)
head(eig.val)
# Out:
#       eigenvalue variance.percent cumulative.variance.percent
# Dim.1 12.3903471 77.4396692       77.43967
# Dim.2  1.7950758 11.2192240       88.65889
# Dim.3  1.0525803  6.5786270       95.23752
# Dim.4  0.2608858  1.6305363       96.86806
# Dim.5  0.2291171  1.4319816       98.30004
# Dim.6  0.1568384  0.9802397       99.28028

# %%
options(repr.plot.width = 20, repr.plot.height = 10)

# %%
barplot(eig.decathlon2.active[, 2], names.arg=1:nrow(eig.decathlon2.active), 
       main = "Variances",
       xlab = "Principal Components",
       ylab = "Percentage of variances",
       col ="steelblue")
# Add connected line segments to the plot
lines(x = 1:nrow(eig.decathlon2.active), 
      eig.decathlon2.active[, 2], 
      type="b", pch=19, col = "red")
# Out:
# Plot with title "Variances"

# %%
fviz_screeplot(res.pca, ncp=54)
# Out:
# plot without title

# %%
var <- get_pca_var(res.pca)
var
# Out:
# Principal Component Analysis Results for variables
#  ===================================================
#   Name       Description
# 1 "$coord"   "Coordinates for the variables"
# 2 "$cor"     "Correlations between variables and dimensions"
# 3 "$cos2"    "Cos2 for the variables"
# 4 "$contrib" "contributions of the variables"

# %%
var$coord
# Out:
#              Dim.1     Dim.2       Dim.3        Dim.4         Dim.5
# PAPI_L1_DCM  0.9920116  0.10149135  0.015684669 -0.0002341753  0.005933646
# PAPI_L3_TCM  0.8305623  0.47386137  0.266697777 -0.0202252957  0.051553989
# PAPI_TOT_INS 0.8712464 -0.36914887 -0.307762315 -0.0236338296 -0.051587121
# PAPI_SP_OPS  -4.993201e-04  8.496744e-03 -6.328791e-03 -1.771438e-04
# PAPI_L2_LDM   5.287770e-03 -2.102577e-03  6.290341e-03  3.375596e-03
# PAPI_L2_STM   1.867990e-04  4.328614e-03 -5.660722e-05  1.104907e-03
# PAPI_BR_CN   -3.827919e-03 -3.042281e-03  8.825781e-03  6.265935e-04
# PAPI_BR_TKN  -4.170881e-03 -3.242994e-03  8.306157e-03  2.143008e-04
# PAPI_TLB_DM   1.211179e-06 -7.851817e-05 -5.336674e-05 -1.535108e-05
# PAPI_L1_LDM  -4.627718e-03 -1.537013e-02  3.435890e-03 -2.625190e-03
# PAPI_L1_STM  -4.809101e-04  6.138377e-03 -6.885820e-03 -1.290694e-03
# PAPI_BR_MSP   1.538244e-02  2.701212e-02  3.438690e-03 -1.056172e-03
# PAPI_LD_INS  -2.928777e-02  1.089241e-02  1.554912e-03  2.843315e-03
# PAPI_SR_INS   5.460333e-03 -4.953555e-03  1.023784e-03 -3.153404e-03
# PAPI_FP_OPS  -2.787794e-03 -1.868897e-03  3.940928e-04 -6.307501e-04
#              Dim.15        Dim.16
# PAPI_L1_DCM   1.749678e-03  3.622553e-04
# PAPI_L3_TCM  -1.233247e-03 -2.002189e-04
# PAPI_TOT_INS  8.062153e-06  5.412354e-06
# PAPI_REF_CYC  1.969359e-05 -1.455145e-05
# PAPI_SP_OPS   2.602749e-06  7.435270e-06
# PAPI_L2_LDM   5.428605e-04  7.773797e-05
# PAPI_L2_STM   3.024693e-04  5.500872e-05
# PAPI_BR_CN   -3.733926e-04  1.572176e-03
# PAPI_BR_TKN   3.549016e-04 -1.603627e-03
# PAPI_TLB_DM   1.579423e-06 -3.817523e-06
# PAPI_L1_LDM  -9.472752e-04 -1.695700e-04
# PAPI_L1_STM  -5.858580e-04 -9.596070e-05
# PAPI_BR_MSP   9.830103e-06 -1.058198e-05
# PAPI_LD_INS  -8.067949e-06 -7.772622e-06
# PAPI_SR_INS   5.473763e-08  3.380372e-06
# PAPI_FP_OPS   1.749250e-06  8.531025e-07

# %%
library(devtools)
library(ggbiplot)
g <- ggbiplot(res.pca, obs.scale = 1, var.scale = 1, groups = res.label, ellipse = TRUE, circle = TRUE)
g <- g + scale_color_discrete(name = '')
g <- g + theme(legend.direction = 'horizontal', legend.position = 'top')
print(g)
# Out:
# plot without title

# %%
# Helper function : 
# Correlation between variables and principal components
var_cor_func <- function(var.loadings, comp.sdev){
  var.loadings*comp.sdev
  }

# Variable correlation/coordinates
loadings <- res.pca$rotation
sdev <- res.pca$sdev

var.coord <- var.cor <- t(apply(loadings, 1, var_cor_func, sdev))
print(var.coord[, 1:4])
# Out:
#                    PC1         PC2          PC3           PC4
# PAPI_L1_DCM  0.9920116  0.10149135  0.015684669 -0.0002341753
# PAPI_L3_TCM  0.8305623  0.47386137  0.266697777 -0.0202252957
# PAPI_TOT_INS 0.8712464 -0.36914887 -0.307762315 -0.0236338296
# PAPI_REF_CYC 0.9969199  0.01544284  0.027217759  0.0133392120
# PAPI_TOT_INS 2.929358e-11
# PAPI_REF_CYC 2.117448e-10
# PAPI_SP_OPS  5.528324e-11
# PAPI_L2_LDM  6.043192e-09
# PAPI_L2_STM  3.025959e-09
# PAPI_BR_CN   2.471738e-06
# PAPI_BR_TKN  2.571618e-06
# PAPI_TLB_DM  1.457348e-11
# PAPI_L1_LDM  2.875400e-08
# PAPI_L1_STM  9.208455e-09
# PAPI_BR_MSP  1.119784e-10
# PAPI_LD_INS  6.041366e-11
# PAPI_SR_INS  1.142692e-11
# PAPI_FP_OPS  7.277839e-13

# %%
comp.cos2 <- apply(var.cos2, 2, sum)

contrib <- function(var.cos2, comp.cos2){var.cos2*100/comp.cos2}

var.contrib <- t(apply(var.cos2,1, contrib, comp.cos2))
print(var.contrib)
# Out:
#                    PC1        PC2          PC3          PC4         PC5
# PAPI_L1_DCM  7.9423688  0.5738194 2.337198e-02 2.101996e-05  0.01536688
# PAPI_L3_TCM  5.5675089 12.5089198 6.757461e+00 1.567976e-01  1.16002440
# PAPI_TOT_INS 6.1263030  7.5913724 8.998614e+00 2.141005e-01  1.16151591
# PAPI_REF_CYC 8.0211573  0.0132853 7.038003e-02 6.820401e-02  1.06902441
# PAPI_SP_OPS  0.1832085 34.7346063 3.148296e+01 5.558117e+00  0.29827036
# PAPI_L2_LDM  5.8054885 10.5054967 4.848882e+00 1.284397e+00  6.48421549
# PAPI_L2_STM  6.4285466  8.2291462 1.107884e+00 5.204106e+00  4.58618845
# PAPI_BR_CN   7.3993829  1.4688461 1.689841e+00 5.509763e-01 13.79063283
# PAPI_BR_TKN  7.4048254  1.4302730 1.682106e+00 5.160422e-01 13.87946602
# PAPI_TLB_DM  5.7972273  4.0689247 5.946655e-04 5.681087e+01 13.52192752
# PAPI_L1_LDM  7.5102005  0.6879314 1.419187e-01 2.591304e-04 10.00672236
# PAPI_L1_STM  6.9471033  0.4599568 9.092584e+00 1.963576e+00  3.47723784
# PAPI_BR_MSP  7.8737417  0.6382816 1.104469e-01 5.954219e-03  1.05024019
# PAPI_LD_INS  5.1243278  7.1486789 2.081462e+01 2.119614e-02  4.12245353
# PAPI_SR_INS  6.5763982  3.1882759 7.014636e+00 1.229764e+00  7.31737431
# PAPI_FP_OPS  5.2922114  6.7521857 6.163691e+00 2.641562e+01 18.05933948
#                      PC6          PC7         PC8         PC9        PC10
# PAPI_L1_DCM   1.39359736  3.547268080  2.75990457  0.02116222  1.11045228
# PAPI_L3_TCM   1.31968064  7.241806996 11.41899008  9.49078465  0.18463114
# PAPI_TOT_INS  0.03770772  0.249145094  0.69939749 27.35137647  1.69919899
# PAPI_REF_CYC  0.42584126  0.011169462  2.90434100  2.43972635  7.16124540
# PAPI_SP_OPS   3.33953537  0.001182435  5.95921003  0.05745183  4.83879225
# PAPI_L2_LDM  12.53176873  1.950813045  0.01191474  0.87092475 36.12582324
# PAPI_L2_STM   1.80929021  0.710265520 52.88219744 11.29478973  4.36775868
# PAPI_BR_CN    2.28518168  2.279230982  3.10832650  0.56558432  0.09621296
# PAPI_BR_TKN   2.24840984  2.329592295  3.14150087  0.62507122  0.08795385
# PAPI_REF_CYC  PAPI_L1_DCM  PAPI_BR_MSP  PAPI_L1_LDM  PAPI_BR_TKN   PAPI_BR_CN
#    8.0211573    7.9423688    7.8737417    7.5102005    7.4048254    7.3993829
#  PAPI_L1_STM  PAPI_SR_INS  PAPI_L2_STM PAPI_TOT_INS  PAPI_L2_LDM  PAPI_TLB_DM
#    6.9471033    6.5763982    6.4285466    6.1263030    5.8054885    5.7972273
#  PAPI_L3_TCM  PAPI_FP_OPS  PAPI_LD_INS  PAPI_SP_OPS
#    5.5675089    5.2922114    5.1243278    0.1832085

# %%
print(sort(var.contrib[,'PC2'],decreasing=TRUE))
# Out:
#  PAPI_SP_OPS  PAPI_L3_TCM  PAPI_L2_LDM  PAPI_L2_STM PAPI_TOT_INS  PAPI_LD_INS
#   34.7346063   12.5089198   10.5054967    8.2291462    7.5913724    7.1486789
#  PAPI_FP_OPS  PAPI_TLB_DM  PAPI_SR_INS   PAPI_BR_CN  PAPI_BR_TKN  PAPI_L1_LDM
#    6.7521857    4.0689247    3.1882759    1.4688461    1.4302730    0.6879314
#  PAPI_BR_MSP  PAPI_L1_DCM  PAPI_L1_STM PAPI_REF_CYC
#    0.6382816    0.5738194    0.4599568    0.0132853

# %%
print(sort(var.contrib[,'PC3'],decreasing=TRUE))
# Out:
#  PAPI_SP_OPS  PAPI_LD_INS  PAPI_L1_STM PAPI_TOT_INS  PAPI_SR_INS  PAPI_L3_TCM
# 3.148296e+01 2.081462e+01 9.092584e+00 8.998614e+00 7.014636e+00 6.757461e+00
#  PAPI_FP_OPS  PAPI_L2_LDM   PAPI_BR_CN  PAPI_BR_TKN  PAPI_L2_STM  PAPI_L1_LDM
# 6.163691e+00 4.848882e+00 1.689841e+00 1.682106e+00 1.107884e+00 1.419187e-01
#  PAPI_BR_MSP PAPI_REF_CYC  PAPI_L1_DCM  PAPI_TLB_DM
# 1.104469e-01 7.038003e-02 2.337198e-02 5.946655e-04

# %%
fviz_pca_var(res.pca, col.var="contrib") + scale_color_gradient2(low="white", mid="blue", high="red", midpoint=50) + theme_minimal()
# Out:
# plot without title

# %%
new_mydata1 = mydata[,5:61]
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_BR_INS))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_BR_NTK))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_BR_PRC))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_FP_INS))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L2_DCA))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L2_DCM))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L2_DCR))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L2_DCW))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L3_DCA))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L3_DCR))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L3_DCW))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L3_LDM))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_LST_INS))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_RES_STL))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_TOT_CYC))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L1_ICA))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L1_ICH))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L1_ICM))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L1_ICR))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L1_TCM))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L2_ICA))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L2_ICH))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L2_ICM))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L2_ICR))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L2_TCA))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L2_TCH))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L2_TCM))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L2_TCR))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L2_TCW))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L3_ICA))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L3_ICR))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L3_TCA))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L3_TCR))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_L3_TCW))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_TLB_IM))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_TLB_TL))



new_mydata1 <- subset(new_mydata1, select = -c(PAPI_BR_UCN))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_TOT_IIS))




new_mydata1 <- subset(new_mydata1, select = -c(PAPI_VEC_SP))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_VEC_DP))
new_mydata1 <- subset(new_mydata1, select = -c(PAPI_DP_OPS))

my_data_ordered1 <- new_mydata1[,order(colnames(new_mydata1))]


options(repr.matrix.max.rows = 100)
options(repr.matrix.max.cols = 100)
res1 <- cor(my_data_ordered1)
dim(res1)
round(res1, 2)
# Out:
# [1] 16 16
#              PAPI_BR_CN PAPI_BR_MSP PAPI_BR_TKN PAPI_FP_OPS PAPI_L1_DCM
# PAPI_BR_CN   1.00       0.92        1.00        0.83        0.94
# PAPI_BR_MSP  0.92       1.00        0.92        0.77        1.00
# PAPI_BR_TKN  1.00       0.92        1.00        0.83        0.94
# PAPI_FP_OPS  0.83       0.77        0.83        1.00        0.76
# PAPI_L1_DCM  0.94       1.00        0.94        0.76        1.00
# PAPI_L1_LDM  0.91       0.96        0.91        0.82        0.96
# PAPI_L1_STM  0.85       0.91        0.85        0.66        0.92
# PAPI_L2_LDM  0.74       0.91        0.74        0.61        0.89
# PAPI_L2_STM  0.82       0.91        0.82        0.64        0.92
# PAPI_L3_TCM  0.76       0.88        0.76        0.56        0.88
# PAPI_LD_INS  0.74       0.74        0.74        0.66        0.75
# PAPI_REF_CYC 0.96       0.99        0.96        0.79        0.99
# PAPI_SP_OPS  0.35       0.09        0.35        0.49        0.08
# PAPI_SR_INS  0.88       0.85        0.88        0.70        0.86
# PAPI_TLB_DM  0.76       0.86        0.76        0.56        0.86
# PAPI_TOT_INS 0.84       0.81        0.84        0.77        0.82
#              PAPI_L1_LDM PAPI_L1_STM PAPI_L2_LDM PAPI_L2_STM PAPI_L3_TCM
# PAPI_BR_CN   0.91         0.85        0.74        0.82        0.76
# PAPI_BR_MSP  0.96         0.91        0.91        0.91        0.88
# PAPI_BR_TKN  0.91         0.85        0.74        0.82        0.76
# PAPI_FP_OPS  0.82         0.66        0.61        0.64        0.56
# PAPI_L1_DCM  0.96         0.92        0.89        0.92        0.88
# PAPI_L1_LDM  1.00         0.86        0.81        0.80        0.75
# PAPI_L1_STM  0.86         1.00        0.74        0.85        0.72
# PAPI_L2_LDM  0.81         0.74        1.00        0.93        0.97
# PAPI_L2_STM  0.80         0.85        0.93        1.00        0.95
# PAPI_L3_TCM  0.75         0.72        0.97        0.95        1.00
# PAPI_LD_INS  0.81         0.83        0.44        0.51        0.37
# PAPI_REF_CYC 0.96         0.92        0.85        0.90        0.85
# PAPI_SP_OPS  0.26        -0.12       -0.08       -0.12       -0.10
# PAPI_SR_INS  0.86         0.89        0.59        0.69        0.58
# PAPI_TLB_DM  0.79         0.78        0.81        0.81        0.81
# PAPI_TOT_INS 0.88         0.86        0.52        0.60        0.47
#              PAPI_LD_INS PAPI_REF_CYC PAPI_SP_OPS PAPI_SR_INS PAPI_TLB_DM
# PAPI_BR_CN   0.74        0.96          0.35       0.88         0.76
# PAPI_BR_MSP  0.74        0.99          0.09       0.85         0.86
# PAPI_BR_TKN  0.74        0.96          0.35       0.88         0.76
# PAPI_FP_OPS  0.66        0.79          0.49       0.70         0.56
# PAPI_L1_DCM  0.75        0.99          0.08       0.86         0.86
# PAPI_L1_LDM  0.81        0.96          0.26       0.86         0.79
# PAPI_L1_STM  0.83        0.92         -0.12       0.89         0.78
# PAPI_L2_LDM  0.44        0.85         -0.08       0.59         0.81
# PAPI_L2_STM  0.51        0.90         -0.12       0.69         0.81
# PAPI_L3_TCM  0.37        0.85         -0.10       0.58         0.81
# PAPI_LD_INS  1.00        0.77          0.14       0.92         0.58
# PAPI_REF_CYC 0.77        1.00          0.16       0.90         0.84
# PAPI_SP_OPS  0.14        0.16          1.00       0.18        -0.05
# PAPI_SR_INS  0.92        0.90          0.18       1.00         0.69
# PAPI_TLB_DM  0.58        0.84         -0.05       0.69         1.00
# PAPI_TOT_INS 0.98        0.85          0.24       0.94         0.64
#              PAPI_TOT_INS
# PAPI_BR_CN   0.84
# PAPI_BR_MSP  0.81
# PAPI_BR_TKN  0.84
# PAPI_FP_OPS  0.77
# PAPI_L1_DCM  0.82
# PAPI_L1_LDM  0.88
# PAPI_L1_STM  0.86
# PAPI_L2_LDM  0.52
# PAPI_L2_STM  0.60
# PAPI_L3_TCM  0.47
# PAPI_LD_INS  0.98
# PAPI_REF_CYC 0.85
# PAPI_SP_OPS  0.24
# PAPI_SR_INS  0.94
# PAPI_TLB_DM  0.64
# PAPI_TOT_INS 1.00

# %%
library(corrplot)


corrplot(res1, tl.col = "black", tl.srt = 90, tl.cex = 0.7, method= "square", order = "AOE", number.cex = 0.5)
# Out:
# Plot with title ""

# %%
corrplot(res1, tl.col = "black", tl.srt = 90, tl.cex = 0.7, method= "square", order = "hclust", number.cex = 0.5, addrect=2)
# Out:
# Plot with title ""

# %%
corrplot(res1, tl.col = "black", tl.srt = 90, tl.cex = 0.7, method= "square", order = "hclust", number.cex = 0.5, addrect=3)
# Out:
# Plot with title ""

# %%
corrplot(res1, tl.col = "black", tl.srt = 90, tl.cex = 0.7, method= "square", order = "hclust", number.cex = 0.5, addrect=4)
# Out:
# Plot with title ""

# %%
corrplot(res1, tl.col = "black", tl.srt = 90, tl.cex = 0.7, method= "square", order = "hclust", number.cex = 0.5, addrect=5)
# Out:
# Plot with title ""

# %%
corrplot(res1, tl.col = "black", tl.srt = 90, tl.cex = 0.7, method= "square", order = "hclust", number.cex = 0.5, addrect=6)
# Out:
# Plot with title ""

# %%
corrplot(res1, tl.col = "black", tl.srt = 90, tl.cex = 0.7, method= "square", order = "hclust", number.cex = 0.5, addrect=7)
# Out:
# Plot with title ""

# %%
corrplot(res1, tl.col = "black", tl.srt = 90, tl.cex = 0.7, method= "square", order = "hclust", number.cex = 0.5, addrect=8)
# Out:
# Plot with title ""

# %%
corrplot(res1, tl.col = "black", tl.srt = 90, tl.cex = 0.7, method= "square", order = "hclust", number.cex = 0.5, addrect=9)
# Out:
# Plot with title ""

# %%
corrplot(res1, tl.col = "black", tl.srt = 90, tl.cex = 0.7, method= "square", order = "hclust", number.cex = 0.5, addrect=10)
# Out:
# Plot with title ""

# %%
corrplot(res1, tl.col = "black", tl.srt = 90, tl.cex = 0.7, method= "square", order = "hclust", number.cex = 0.5, addrect=11)
# Out:
# Plot with title ""

# %%
corrplot(res1, tl.col = "black", tl.srt = 90, tl.cex = 0.7, method= "square", order = "hclust", number.cex = 0.5, addrect=12)
# Out:
# Plot with title ""

# %%
corrplot(res1, tl.col = "black", tl.srt = 90, tl.cex = 0.7, method= "square", order = "hclust", number.cex = 0.5, addrect=13)
# Out:
# Plot with title ""

# %%
corrplot(res1, tl.col = "black", tl.srt = 90, tl.cex = 0.7, method= "square", order = "hclust", number.cex = 0.5, addrect=14)
# Out:
# Plot with title ""

# %%
corrplot(res1, tl.col = "black", tl.srt = 90, tl.cex = 0.7, method= "square", order = "hclust", number.cex = 0.5, addrect=15)
# Out:
# Plot with title ""

# %%
corrplot(res1, tl.col = "black", tl.srt = 90, tl.cex = 0.7, method= "square", order = "hclust", number.cex = 0.5, addrect=16)
# Out:
# Plot with title ""

# %%
corrplot(res1, tl.col = "black", tl.srt = 90, tl.cex = 0.7, method= "square", order = "FPC", number.cex = 0.5)
# Out:
# Plot with title ""

# %%
corrplot(res1, tl.col = "black", tl.srt = 90, tl.cex = 0.7, method= "square", order = "alphabet", number.cex = 0.5)
# Out:
# Plot with title ""
